# %%
import random as ran

# %%
# this function only use ASCII codes 

def incode(t):
  list = []
  for char in t:
    list.append(ord(char) + 10)
  return list

# %%
def decode(list):
  str = ""
  for item in list:
    str += chr(item - 10)
  return str

# %%
# The key will be a dynamic dictionary that generate to code and decode datas

def key_generator():
  for i in range(ord('A'), ord('z') + 1):
    new_key = ran.randint(488, 8521)
    while(new_key in key.keys()):
      new_key = ran.randint(488, 8521)
    key[chr(i)] = new_key
  while(new_key in key.keys()):
    new_key = ran.randint(488, 8521)
  key[' '] = new_key
  return key

# %%
key = {}
key = key_generator()
key
# Out:
# {'A': 4295,
#  'B': 5824,
#  'C': 7773,
#  'D': 5174,
#  'E': 4438,
#  'F': 802,
#  'G': 5077,
#  'H': 7747,
#  'I': 4123,
#  'J': 4772,
#  'K': 2060,
#  'L': 5086,
#  'M': 4383,
#  'N': 7832,
#  'O': 4481,
#  'P': 513,
#  'Q': 1738,
#  'R': 3810,
#  'S': 8163,
#  'T': 6030,
#  'U': 1495,
#  'V': 8497,
#  'W': 1219,
#  'X': 7078,
#  'Y': 858,
#  'Z': 938,
#  '[': 2195,
#  '\\': 3521,
#  ']': 7045,
#  '^': 4307,
#  '_': 7441,
#  '`': 5243,
#  'a': 1187,
#  'b': 3352,
#  'c': 6844,
#  'd': 3012,
#  'e': 2104,
#  'f': 4227,
#  'g': 4368,
#  'h': 5526,
#  'i': 5037,
#  'j': 2102,
#  'k': 7771,
#  'l': 2089,
#  'm': 2047,
#  'n': 1558,
#  'o': 6161,
#  'p': 2210,
#  'q': 726,
#  'r': 4929,
#  's': 3482,
#  't': 4091,
#  'u': 2715,
#  'v': 3811,
#  'w': 6931,
#  'x': 7802,
#  'y': 1537,
#  'z': 1628,
#  ' ': 1628}

# %%
def enckey(text):
    for char in text:
        list.append(key[char])
    return list

# %%
incode("Hello World!")
# Out:
# [82, 111, 118, 118, 121, 42, 97, 121, 124, 118, 110, 43]

# %%
decode([82, 111, 118, 118, 121, 42, 97, 121, 124, 118, 110, 43])
# Out:
# 'Hello World!'
